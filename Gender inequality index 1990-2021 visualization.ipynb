# %%
#importing libraries needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset into jupyter notebooks
Df = pd.read_csv(r"C:\Users\Marc\Downloads\archive 4.zip")

Df
# Out:
#     ISO3               Country Continent           Hemisphere  \
# 0    AFG           Afghanistan      Asia  Northern Hemisphere
# 1    AGO                Angola    Africa  Southern Hemisphere
# 2    ALB               Albania    Europe  Northern Hemisphere
# 3    AND               Andorra    Europe  Northern Hemisphere
# 4    ARE  United Arab Emirates      Asia  Northern Hemisphere
# ..   ...                   ...       ...                  ...
# 190  WSM                 Samoa   Oceania  Southern Hemisphere
# 191  YEM                 Yemen      Asia  Northern Hemisphere
# 192  ZAF          South Africa    Africa  Southern Hemisphere
# 193  ZMB                Zambia    Africa  Southern Hemisphere
# 194  ZWE              Zimbabwe    Africa  Southern Hemisphere
#
#     Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                        Low                      SA            180.0
# 1                     Medium                     SSA            148.0
# ...

# %%
#To show all columns and rows of the dataset 
pd.set_option('display.max.rows', 196)
pd.set_option('display.max.columns', 41)

# %%
#studying dataset before EDA begins
Df
# Out:
#     ISO3                               Country Continent           Hemisphere  \
# 0    AFG                           Afghanistan      Asia  Northern Hemisphere
# 1    AGO                                Angola    Africa  Southern Hemisphere
# 2    ALB                               Albania    Europe  Northern Hemisphere
# 3    AND                               Andorra    Europe  Northern Hemisphere
# 4    ARE                  United Arab Emirates      Asia  Northern Hemisphere
# 5    ARG                             Argentina   America  Southern Hemisphere
# 6    ARM                               Armenia      Asia  Northern Hemisphere
# 7    ATG                   Antigua and Barbuda   America  Northern Hemisphere
# 8    AUS                             Australia   Oceania  Southern Hemisphere
# 9    AUT                               Austria    Europe  Northern Hemisphere
# 10   AZE                            Azerbaijan      Asia  Northern Hemisphere
# ...

# %%
#order table using the country column in ascending order
Df.sort_values(by = 'Country')
# Out:
#     ISO3                               Country Continent           Hemisphere  \
# 0    AFG                           Afghanistan      Asia  Northern Hemisphere
# 2    ALB                               Albania    Europe  Northern Hemisphere
# 49   DZA                               Algeria    Africa  Northern Hemisphere
# 3    AND                               Andorra    Europe  Northern Hemisphere
# 1    AGO                                Angola    Africa  Southern Hemisphere
# 7    ATG                   Antigua and Barbuda   America  Northern Hemisphere
# 5    ARG                             Argentina   America  Southern Hemisphere
# 6    ARM                               Armenia      Asia  Northern Hemisphere
# 8    AUS                             Australia   Oceania  Southern Hemisphere
# 9    AUT                               Austria    Europe  Northern Hemisphere
# 10   AZE                            Azerbaijan      Asia  Northern Hemisphere
# ...

# %%
#to check entire table correlation
correlation = Df.corr()

correlation
# Out:
# C:\Users\Marc\AppData\Local\Temp\ipykernel_7116\3956058314.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = Df.corr()
#                                 HDI Rank (2021)  GII Rank (2021)  \
# HDI Rank (2021)                        1.000000         0.925475
# GII Rank (2021)                        0.925475         1.000000
# Gender Inequality Index (1990)         0.869440         0.911558
# Gender Inequality Index (1991)         0.872785         0.913732
# Gender Inequality Index (1992)         0.876063         0.915518
# Gender Inequality Index (1993)         0.877829         0.915153
# Gender Inequality Index (1994)         0.879556         0.914236
# Gender Inequality Index (1995)         0.880407         0.916954
# Gender Inequality Index (1996)         0.884497         0.920824
# ...

# %%
#to pick visualizations design 
print(plt.style.available)
plt.style.use('Solarize_Light2')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#plotting the table correlation
plt.figure(figsize=(20, 15))
sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
#checking if there's a correlation between HDI and GII
plt.scatter(x=Df['HDI Rank (2021)'], y=Df['Gender Inequality Index (2021)'])

plt.title('Correlation between Human Development Index Rank 2021 and Gender Inequality Index (2021)')
plt.xlabel('Human Development Index Rank')
plt.ylabel('Gender Inequality Index')

plt.show()

# %%
#setting the country column as table index 
Df.set_index('Country', inplace=True)

# %%
sorted = Df.sort_values(by='GII Rank (2021)')

# %%
#exploring the top 10 countries with the lowest gender inequality index
Top_10_countries = sorted.head(10)

Top_10_countries
# Out:
#             ISO3 Continent           Hemisphere Human Development Groups  \
# Country
# Denmark      DNK    Europe  Northern Hemisphere                Very High
# Norway       NOR    Europe  Northern Hemisphere                Very High
# Switzerland  CHE    Europe  Northern Hemisphere                Very High
# Sweden       SWE    Europe  Northern Hemisphere                Very High
# Netherlands  NLD    Europe  Northern Hemisphere                Very High
# Finland      FIN    Europe  Northern Hemisphere                Very High
# Singapore    SGP      Asia  Northern Hemisphere                Very High
# Iceland      ISL    Europe  Northern Hemisphere                Very High
# Luxembourg   LUX    Europe  Northern Hemisphere                Very High
# Belgium      BEL    Europe  Northern Hemisphere                Very High
#
#             UNDP Developing Regions  HDI Rank (2021)  GII Rank (2021)  \
# Country
# Denmark                         NaN              6.0              1.0
# ...

# %%
#extracting only the columns needed for visualization
columns = ['Gender Inequality Index (1990)', 'Gender Inequality Index (1991)', 'Gender Inequality Index (1992)', 
           'Gender Inequality Index (1993)', 'Gender Inequality Index (1994)', 'Gender Inequality Index (1995)', 
           'Gender Inequality Index (1996)', 'Gender Inequality Index (1997)', 'Gender Inequality Index (1998)', 
           'Gender Inequality Index (1999)', 'Gender Inequality Index (2000)', 'Gender Inequality Index (2001)', 
           'Gender Inequality Index (2002)', 'Gender Inequality Index (2003)', 'Gender Inequality Index (2004)', 
           'Gender Inequality Index (2005)', 'Gender Inequality Index (2006)', 'Gender Inequality Index (2007)', 
           'Gender Inequality Index (2008)', 'Gender Inequality Index (2009)', 'Gender Inequality Index (2010)', 
           'Gender Inequality Index (2011)', 'Gender Inequality Index (2012)', 'Gender Inequality Index (2013)', 
           'Gender Inequality Index (2014)', 'Gender Inequality Index (2015)', 'Gender Inequality Index (2016)', 
           'Gender Inequality Index (2017)', 'Gender Inequality Index (2018)', 'Gender Inequality Index (2019)', 
           'Gender Inequality Index (2020)', 'Gender Inequality Index (2021)']

# %%
#making these columns into a dataframe 
Top10 = Top_10_countries[columns]

Top10
# Out:
#              Gender Inequality Index (1990)  Gender Inequality Index (1991)  \
# Country
# Denmark                               0.090                           0.090
# Norway                                0.132                           0.129
# Switzerland                           0.124                           0.130
# Sweden                                0.101                           0.100
# Netherlands                           0.118                           0.122
# Finland                               0.108                           0.104
# Singapore                             0.261                           0.244
# Iceland                               0.187                           0.183
# Luxembourg                            0.213                           0.203
# Belgium                               0.180                           0.179
#
#              Gender Inequality Index (1992)  Gender Inequality Index (1993)  \
# Country
# ...

# %%
#picking preferred line colors for plot
line_colors = sns.color_palette('deep', 10).as_hex()

# %%
#plot
Top10.T.plot(figsize = (20, 10), linewidth=5, color=line_colors)

plt.legend(fontsize=16)
plt.title('Top 10 Ranked Countries based on Gender Inequality Index (1990-2021)')
plt.xlabel('Year')
plt.ylabel('Gender Inequality Index')
# Out:
# Text(0, 0.5, 'Gender Inequality Index')

# %%
#exploring the top 10 countries with the highest gender inequality index
bottom_10_countries = sorted[160:170]

bottom_10_countries
# Out:
#                          ISO3 Continent           Hemisphere  \
# Country
# Mauritania                MRT    Africa  Northern Hemisphere
# Sierra Leone              SLE    Africa  Northern Hemisphere
# Haiti                     HTI   America  Northern Hemisphere
# Liberia                   LBR    Africa  Northern Hemisphere
# Chad                      TCD    Africa  Northern Hemisphere
# Central African Republic  CAF    Africa  Northern Hemisphere
# Afghanistan               AFG      Asia  Northern Hemisphere
# Nigeria                   NGA    Africa  Northern Hemisphere
# Papua New Guinea          PNG   Oceania  Southern Hemisphere
# Yemen                     YEM      Asia  Northern Hemisphere
#
#                          Human Development Groups UNDP Developing Regions  \
# Country
# Mauritania                                 Medium                     SSA
# Sierra Leone                                  Low                     SSA
# ...

# %%
#extracting only the columns needed for visualization
columns = ['Gender Inequality Index (1990)', 'Gender Inequality Index (1991)', 'Gender Inequality Index (1992)', 
           'Gender Inequality Index (1993)', 'Gender Inequality Index (1994)', 'Gender Inequality Index (1995)', 
           'Gender Inequality Index (1996)', 'Gender Inequality Index (1997)', 'Gender Inequality Index (1998)', 
           'Gender Inequality Index (1999)', 'Gender Inequality Index (2000)', 'Gender Inequality Index (2001)', 
           'Gender Inequality Index (2002)', 'Gender Inequality Index (2003)', 'Gender Inequality Index (2004)', 
           'Gender Inequality Index (2005)', 'Gender Inequality Index (2006)', 'Gender Inequality Index (2007)', 
           'Gender Inequality Index (2008)', 'Gender Inequality Index (2009)', 'Gender Inequality Index (2010)', 
           'Gender Inequality Index (2011)', 'Gender Inequality Index (2012)', 'Gender Inequality Index (2013)', 
           'Gender Inequality Index (2014)', 'Gender Inequality Index (2015)', 'Gender Inequality Index (2016)', 
           'Gender Inequality Index (2017)', 'Gender Inequality Index (2018)', 'Gender Inequality Index (2019)', 
           'Gender Inequality Index (2020)', 'Gender Inequality Index (2021)']

# %%
#making these columns into a dataframe
bottom10 = bottom_10_countries[columns]

bottom10
# Out:
#                           Gender Inequality Index (1990)  \
# Country
# Mauritania                                         0.808
# Sierra Leone                                         NaN
# Haiti                                                NaN
# Liberia                                              NaN
# Chad                                                 NaN
# Central African Republic                           0.751
# Afghanistan                                          NaN
# Nigeria                                              NaN
# Papua New Guinea                                   0.671
# Yemen                                                NaN
#
#                           Gender Inequality Index (1991)  \
# Country
# Mauritania                                         0.806
# Sierra Leone                                         NaN
# Haiti                                                NaN
# Liberia                                              NaN
# ...

# %%
#plot
bottom10.T.plot(figsize = (20, 10), linewidth=2.5, color=line_colors)

plt.legend(fontsize=16)
plt.title('Bottom 10 Ranked Countries based on Gender Inequality Index (1990-2021)')
plt.xlabel('Year')
plt.ylabel('Gender Inequality Index')
# Out:
# Text(0, 0.5, 'Gender Inequality Index')
